# %% [markdown]
# <a href="https://colab.research.google.com/github/leeseunghwan0409/AIFFEL_Online_Quest/blob/main/%EC%BD%94%EB%93%9C%ED%8E%98%EC%96%B4%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word = input('입력 : ').replace(' ', '')

is_right = True
for i in range(len(word) // 2):
  if word[i] != word[-1 - i]:
    is_right = False
    break

print(is_right)
# Out:
# 입력 : 토마토
# True
